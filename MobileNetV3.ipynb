# %% [markdown]
# <a href="https://colab.research.google.com/github/rcgopi100/CNNPretrainedMobileNetV3/blob/main/MobileNetV3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Import Numpy, Keras Image and MobileNetV3 libraries
import numpy as np
from keras.preprocessing import image
from tensorflow.keras.applications import MobileNetV3Large

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8de84a7b-6cbf-489d-99d1-bb3b8b223a5a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8de84a7b-6cbf-489d-99d1-bb3b8b223a5a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving peacock.jpg to peacock.jpg

# %%
model = MobileNetV3Large(weights='imagenet')
model
# Out:
# WARNING:tensorflow:`input_shape` is undefined or non-square, or `rows` is not 224. Weights for input shape (224, 224) will be loaded as the default.

# %%
img = image.load_img('peacock.jpg', target_size=(224, 224))
img
# Out:
# <PIL.Image.Image image mode=RGB size=224x224 at 0x7EFE6DBF6810>

# %%
#convert image to array
input_img = image.img_to_array(img)
input_img = np.expand_dims(input_img, axis=0)
input_img = mobilenet_v3.preprocess_input(input_img)
input_img
# Out:
# array([[[[  7.,   3.,   0.],
#          [ 20.,  16.,  15.],
#          [154., 154., 154.],
#          ...,
#          [126., 188., 113.],
#          [ 60.,  42.,  54.],
#          [  5., 247., 137.]],
#
#         [[  5.,   1.,   0.],
#          [ 30.,  22.,  20.],
#          [  6.,   0.,   0.],
#          ...,
#          [161., 176.,  47.],
#          [ 56.,  44.,  22.],
#          [ 11., 241., 143.]],
#
#         [[ 10.,   6.,   7.],
#          [ 68.,  58.,  57.],
#          [  8.,   0.,   0.],
#          ...,
#          [ 81., 184.,  77.],
#          [ 60.,  47.,  56.],
#          [ 14., 165.,  98.]],
#
#         ...,
#
#         [[ 36., 126.,  28.],
#          [ 69., 106.,  39.],
#          [ 19.,  71.,   0.],
#          ...,
#          [123.,  98.,   5.],
#          [158., 142.,   7.],
#          [183., 146.,  13.]],
#
#         [[  0.,  82.,   0.],
#          [ 19.,  96.,  26.],
#          [  1.,  20.,   0.],
#          ...,
#          [141., 120.,   0.],
# ...

# %%
predict_img = model.predict(input_img)
predict_img
# Out:
# array([[1.00958438e-04, 3.89771012e-05, 2.96268045e-05, 4.66231977e-05,
#         2.43979608e-04, 6.75260162e-05, 1.62891331e-04, 1.52741733e-04,
#         1.18651180e-04, 1.25958890e-04, 1.01109516e-04, 1.99558563e-05,
#         7.53382628e-05, 4.96858775e-05, 2.69871292e-04, 2.26983888e-04,
#         5.06542965e-05, 1.77971000e-04, 1.77117457e-04, 4.05683277e-05,
#         1.31872293e-04, 7.34028145e-05, 2.33783911e-04, 7.91826751e-05,
#         3.71583359e-04, 1.00450678e-04, 7.34575806e-05, 1.27178617e-04,
#         9.41710314e-05, 3.20282561e-05, 1.75191934e-04, 8.07572724e-05,
#         1.03553859e-04, 1.04397994e-04, 1.53898160e-04, 6.99935772e-05,
#         8.25749812e-05, 4.46616068e-05, 4.46031627e-05, 4.46002523e-04,
#         8.37241460e-05, 2.42756578e-05, 2.82048568e-04, 1.54475449e-04,
#         5.33698621e-05, 5.25919240e-05, 1.42859222e-04, 9.07109003e-04,
#         1.68442362e-04, 1.43052122e-04, 8.18642729e-05, 1.91214713e-04,
# ...

# %%
top_five_predict = mobilenet_v3.decode_predictions(predict_img, top=5)
top_five_predict
# Out:
# [[('n01806143', 'peacock', 0.8399663),
#   ('n02319095', 'sea_urchin', 0.004589346),
#   ('n04417672', 'thatch', 0.0020714307),
#   ('n04507155', 'umbrella', 0.002066315),
#   ('n04275548', 'spider_web', 0.0019399849)]]
